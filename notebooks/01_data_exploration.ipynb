# %%
import pandas as pd
import os

# %%
cwd = os.getcwd()
print(cwd)
# Out:
# /Users/bibashnepali/Desktop/AI_Data_Intelligence/ai_data_intelligence/notebooks

# %%
load_data = pd.read_csv("/Users/bibashnepali/Desktop/AI_Data_Intelligence/ai_data_intelligence/data/games.csv")

# %%
df = pd.DataFrame(load_data)

# %%
df.head(10)
# Out:
#    game_id                       title          platform platform_type  \
# 0  G000001              eFootball 2023          Game Boy      Handheld
# 1  G000002                      Doom 3              Xbox       Console
# 2  G000003                 God of Fire                PC            PC
# 3  G000004    Call of Duty: Rising Sun  Mobile (Android)        Mobile
# 4  G000005                  Fortnite 3       Nintendo 64       Console
# 5  G000006  Need for Speed: Shadow War                PC            PC
# 6  G000007                  Valorant 3               NES       Console
# 7  G000008                   FIFA 2024               NES       Console
# 8  G000009         Battlefield Odyssey          Xbox 360       Console
# 9  G000010              Kirby's Knight        Atari 2600       Console
#
#   platform_maker  platform_generation          genre  year  \
# 0       Nintendo                    4         Sports  1990
# 1      Microsoft                    6         Rhythm  2004
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 35 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   game_id                             50000 non-null  str
#  1   title                               50000 non-null  str
#  2   platform                            50000 non-null  str
#  3   platform_type                       50000 non-null  str
#  4   platform_maker                      50000 non-null  str
#  5   platform_generation                 50000 non-null  int64
#  6   genre                               50000 non-null  str
#  7   year                                50000 non-null  int64
#  8   publisher                           50000 non-null  str
#  9   developer                           50000 non-null  str
#  10  publisher_region                    50000 non-null  str
#  11  publisher_tier                      50000 non-null  str
# ...

# %%
df.describe()
# Out:
#         game_id             title platform platform_type platform_maker  \
# count     50000             50000    50000         50000          50000
# unique    50000              1391       33             7              8
# top     G000001  Devil May Ascend       PC       Console       Nintendo
# freq          1               195     6305         24495          16815
# mean        NaN               NaN      NaN           NaN            NaN
# std         NaN               NaN      NaN           NaN            NaN
# min         NaN               NaN      NaN           NaN            NaN
# 25%         NaN               NaN      NaN           NaN            NaN
# 50%         NaN               NaN      NaN           NaN            NaN
# 75%         NaN               NaN      NaN           NaN            NaN
# max         NaN               NaN      NaN           NaN            NaN
#
#         platform_generation   genre          year publisher developer  ...  \
# ...

# %%
if (df.isnull().sum().sum() == 0):
    print("No missing values in the dataset.")
# Out:
# No missing values in the dataset.
